# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("films.xlsx", sheet_name='COMEDY')
df
# Out:
#     Entry                          Film  \
# 0       1                    Annie Hall
# 1       2                         Borat
# 2       3              Some Like it Hot
# 3       4                  Team America
# 4       5                Dr Strangelove
# 5       5               The Ladykillers
# 6       7                     Duck Soup
# 7       7                      Rushmore
# 8       9        Kind Hearts & Coronets
# 9      10  Monty Python’s Life of Brian
# 10     11                     Airplane!
# 11     12                      Election
# 12     12               His Girl Friday
# 13     12              The Big Lebowski
# 14     15            This Is Spinal Tap
# 15     16              Bringing Up Baby
# 16     17  There’s Something About Mary
# 17     18            Dazed and Confused
# 18     18                          MASH
# 19     20                 Groundhog Day
# 20     21                      Clueless
# 21     22            The Great Dictator
# ...

# %%
df_list = pd.read_excel("films.xlsx", sheet_name=None)
type(df_list)
# Out:
# dict

# %%
df_list.keys()
# Out:
# dict_keys(['ROMANCE', 'CRIME', 'COMEDY', 'ACTION', 'ARTHOUSE AND DRAMA', 'SCI-FI AND FANTASY', 'HORROR'])

# %%
df_list.get("CRIME")
# Out:
#     Entry                                Film  \
# 0       1                           Chinatown
# 1       2                       Touch of Evil
# 2       3                             Vertigo
# 3       4                            Badlands
# 4       5                            Rashomon
# 5       6                    Double Indemnity
# 6       7                          Get Carter
# 7       8                        Pulp Fiction
# 8       9                              Hidden
# 9      10                          Goodfellas
# 10     11                    The Conversation
# 11     12                      Bonnie & Clyde
# 12     13                         The Killing
# 13     14                   French Connection
# 14     15                       The Big Sleep
# 15     16                        La Ceremonie
# 16     17                         Point Blank
# 17     18                         Hard Boiled
# 18     19                    Long Good Friday
# ...

# %%
df.to_excel("crime.xls")
# Out:
# /var/folders/11/hff4y9v9091g8skr6mkm__l40000gn/T/ipykernel_10439/2749786676.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel("crime.xls")
